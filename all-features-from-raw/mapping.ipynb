# %%
import json
import pandas as pd
bundle_mapping = json.load(open("bundle_mapping_json.json"))
bundle_features = pd.read_csv("bundle_features_with_depth.csv",index_col=[0])
bundle_features["mapped_bundle_id"] = bundle_features["bundle_id"].apply(lambda x: bundle_mapping[str(x)])
bundle_features.to_csv("bundle_features_with_depth_mapped_id.csv")

# %%
item_mapping = json.load(open("item_mapping_json.json"))
item_features = pd.read_csv("item_features_with_depth.csv",index_col=[0])
item_features["mapped_item_id"] = item_features["item_id"].apply(lambda x: item_mapping[str(x)])
item_features.to_csv("item_features_with_depth_mapped_id.csv")

# %%
user_mapping = json.load(open("user_mapping_json.json"))
user_features = pd.read_csv("user_features_with_depth.csv",index_col=[0])
user_features["mapped_user_id"] = user_features["user_id"].apply(lambda x: user_mapping[str(x)])
user_features.to_csv("user_features_with_depth_mapped_id.csv")

# %%
user_features
# Out:
#                  user_id  user_depth  user_width mapped_user_id
# 0      76561197960269200    0.228855       0.875              0
# 1      76561197960270504    0.163600       0.875              1
# 2      76561197960270742    0.944925       0.500              2
# 3      76561197960271609    0.486380       0.250              3
# 4      76561197960271888    0.668127       0.625              4
# ...                  ...         ...         ...            ...
# 68707  76561198327778018    1.000000       0.125          70907
# 68708  76561198328421116    0.419540       0.125          70908
# 68709  76561198328629223    0.000000       0.125          70909
# 68710  76561198328946162    0.998454       0.250          70910
# 68711  76561198329548331    0.931224       0.375          70911
#
# [68712 rows x 4 columns]
